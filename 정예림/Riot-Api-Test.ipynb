# %%
pip install riotwatcher
# Out:
# Requirement already satisfied: riotwatcher in /usr/local/lib/python3.7/dist-packages (3.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from riotwatcher) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->riotwatcher) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->riotwatcher) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->riotwatcher) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->riotwatcher) (1.24.3)

# %%
from riotwatcher import LolWatcher, ApiError
from pprint import pprint
from datetime import datetime, timedelta
import os

# %%
f = open("api.txt", "r")
api = f.readline()

# %%
lol_watcher = LolWatcher(api)

my_region = 'kr'

# %%
me = lol_watcher.summoner.by_name(my_region, 'hide on bush')

print(me)
# Out:
# {'id': 'CAG1ceWpVhAGsAT0JM07mg6qo_CzciOzukeJBzZPM5xQTw', 'accountId': 'RHoWEOPb8A3KYDPLB5pjm-25TaIHQEnbKu7JPEnP-Cnd', 'puuid': '-9Bic1iTaYFyiLVDRtzbRYFXS_QRMmPqoITpdApXhMnygLYWWUR1BoKoooYyNDZA2g6JInb9QW305w', 'name': 'Hide on bush', 'profileIconId': 6, 'revisionDate': 1630052504000, 'summonerLevel': 494}

# %%
my_ranked_stats = lol_watcher.league.by_summoner(my_region, me['id'])
pprint(my_ranked_stats)
# Out:
# [{'freshBlood': True,
#   'hotStreak': False,
#   'inactive': False,
#   'leagueId': 'd1ff3466-6c02-33b0-8085-9fa6a8b82dd5',
#   'leaguePoints': 786,
#   'losses': 626,
#   'queueType': 'RANKED_SOLO_5x5',
#   'rank': 'I',
#   'summonerId': 'CAG1ceWpVhAGsAT0JM07mg6qo_CzciOzukeJBzZPM5xQTw',
#   'summonerName': 'Hide on bush',
#   'tier': 'CHALLENGER',
#   'veteran': False,
#   'wins': 680}]

# %%
my_matches = lol_watcher.match.matchlist_by_account(my_region, me['accountId'])

last_match = my_matches['matches'][0]
match_detail = lol_watcher.match.by_id(my_region, last_match['gameId'])

pprint(match_detail)
# Out:
# {'gameCreation': 1630519481968,
#  'gameDuration': 1916,
#  'gameId': 5428625879,
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '11.17.394.4489',
#  'mapId': 11,
#  'participantIdentities': [{'participantId': 1,
#                             'player': {'accountId': 'xfEZaL9S2SORJFsxgRJ-XXa4Fd1Ef_bnQiGePuRDQn0Ur-uKZBCbv7WG',
#                                        'currentAccountId': 'xfEZaL9S2SORJFsxgRJ-XXa4Fd1Ef_bnQiGePuRDQn0Ur-uKZBCbv7WG',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/2750817193985568',
#                                        'platformId': 'KR',
#                                        'profileIcon': 3542,
#                                        'summonerId': 'MayRTC3yZg4eogb-NVbCMQQTk5QQaCo4y9dvjVVfebXL7DvG1qWvKvSheg',
#                                        'summonerName': '가오 띵띵'}},
#                            {'participantId': 2,
#                             'player': {'accountId': 'V35gX15U8fimdC0dHNiVW4TbYQTpTCm-OEmqI35u5qo8R_OVrokTMPEH',
#                                        'currentAccountId': 'V35gX15U8fimdC0dHNiVW4TbYQTpTCm-OEmqI35u5qo8R_OVrokTMPEH',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/2693932725798528',
#                                        'platformId': 'KR',
#                                        'profileIcon': 3378,
#                                        'summonerId': '5g3sJRviT1XA9LuuMpJV7yLwXeDQsywjzsy5KwTMLX5pZE4qCcTOrsPhRw',
#                                        'summonerName': 'Boss Baby 2'}},
#                            {'participantId': 3,
#                             'player': {'accountId': 'miMTvW5cNCvyaduL5wRob4k5D4xkpmcXYEXo-FgXrCPpW61RWPNoyUDT',
#                                        'currentAccountId': 'miMTvW5cNCvyaduL5wRob4k5D4xkpmcXYEXo-FgXrCPpW61RWPNoyUDT',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/2639440437667808',
#                                        'platformId': 'KR',
#                                        'profileIcon': 4997,
#                                        'summonerId': 'gd1awmkipSvbTIedtQKnrzJsyifp9nfsOAcArkd4SCbtN1-PZ3Ac6ykXtA',
#                                        'summonerName': 'Diabloi'}},
#                            {'participantId': 4,
#                             'player': {'accountId': 'zLUNud6wEiYYZaICkHaWUWVrLYNJZx9Tbvlszm7B2aJsIBZpA2R01mXR',
#                                        'currentAccountId': 'zLUNud6wEiYYZaICkHaWUWVrLYNJZx9Tbvlszm7B2aJsIBZpA2R01mXR',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/2721082969588800',
#                                        'platformId': 'KR',
#                                        'profileIcon': 4982,
#                                        'summonerId': 'K2XRfPzOufhMIp5rx9__Q5eNj3Tcwh64iDvJLyZoTcTi4gEyT5FP552fbw',
#                                        'summonerName': '   Lay   waste'}},
#                            {'participantId': 5,
#                             'player': {'accountId': 'cmK9XWIxlB_BmzPcMAN-quwufRim8ligPtkozjZul-phveXCYfcw9PaL',
#                                        'currentAccountId': 'cmK9XWIxlB_BmzPcMAN-quwufRim8ligPtkozjZul-phveXCYfcw9PaL',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/2625016602257152',
#                                        'platformId': 'KR',
#                                        'profileIcon': 7,
#                                        'summonerId': 'O6vE3IzrLLl58YrGJCe7VB7RzKv2Ts-0aw0iEfnmhnS_N60drjSWho-ZtQ',
#                                        'summonerName': '백 쿠'}},
#                            {'participantId': 6,
#                             'player': {'accountId': 'c4rbpi6mAug_SDmdz7AeCBf5FLwBRhlH3Rhuwg86pECBBMC2JtGMEf0Y',
#                                        'currentAccountId': 'c4rbpi6mAug_SDmdz7AeCBf5FLwBRhlH3Rhuwg86pECBBMC2JtGMEf0Y',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/2446294266481984',
#                                        'platformId': 'KR',
#                                        'profileIcon': 4408,
#                                        'summonerId': 'bt9j8KhqYrHQ3uzmDv66fia-QEGNrW648TEmFqy7RlAz3EI',
#                                        'summonerName': 'KT R MID'}},
#                            {'participantId': 7,
#                             'player': {'accountId': '38VC2-97FqcQoMNlvj6PC4JVCGQqnLqg2lMWFDDqpBBe',
#                                        'currentAccountId': '38VC2-97FqcQoMNlvj6PC4JVCGQqnLqg2lMWFDDqpBBe',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/7399033',
#                                        'platformId': 'KR',
#                                        'profileIcon': 7,
#                                        'summonerId': 'nsSrsh7mtO0j9errRazXJY44q5rV6j0WnBCUZAj-QUhVYx0',
#                                        'summonerName': 'skewk'}},
#                            {'participantId': 8,
#                             'player': {'accountId': 'RHoWEOPb8A3KYDPLB5pjm-25TaIHQEnbKu7JPEnP-Cnd',
#                                        'currentAccountId': 'RHoWEOPb8A3KYDPLB5pjm-25TaIHQEnbKu7JPEnP-Cnd',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/3440481',
#                                        'platformId': 'KR',
#                                        'profileIcon': 6,
#                                        'summonerId': 'CAG1ceWpVhAGsAT0JM07mg6qo_CzciOzukeJBzZPM5xQTw',
#                                        'summonerName': 'Hide on bush'}},
#                            {'participantId': 9,
#                             'player': {'accountId': 'BaXl4ZwRr3Ii9CJbGSi0LCZMtsix6iM_fdcs8SB9nf8YnNd2u6liKUkp',
#                                        'currentAccountId': 'BaXl4ZwRr3Ii9CJbGSi0LCZMtsix6iM_fdcs8SB9nf8YnNd2u6liKUkp',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/2556848993363936',
#                                        'platformId': 'KR',
#                                        'profileIcon': 23,
#                                        'summonerId': 'H6zJCb7vZmT-qWaat3FYGKi_nbYGF930MERC2MLH1Z0c9nYL',
#                                        'summonerName': 'Mangja'}},
#                            {'participantId': 10,
#                             'player': {'accountId': 'l1AaQcFtpniQ6F8WZwq6BDLrBdHxIQRtI9Cw-pAZPjMu_7r3pN1yBw4G',
#                                        'currentAccountId': 'l1AaQcFtpniQ6F8WZwq6BDLrBdHxIQRtI9Cw-pAZPjMu_7r3pN1yBw4G',
#                                        'currentPlatformId': 'KR',
#                                        'matchHistoryUri': '/v1/stats/player_history/KR/2504677375526400',
#                                        'platformId': 'KR',
#                                        'profileIcon': 4895,
#                                        'summonerId': 'NCdYdGaNdHs_oZ00EZZIRLZZoJDy_YPYvebbt9HBeaMQDvui',
#                                        'summonerName': '소년가장 원딜'}}],
#  'participants': [{'championId': 523,
#                    'participantId': 1,
#                    'spell1Id': 7,
#                    'spell2Id': 4,
#                    'stats': {'assists': 6,
#                              'champLevel': 15,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 10915,
#                              'damageDealtToTurrets': 10554,
#                              'damageSelfMitigated': 15263,
#                              'deaths': 6,
#                              'doubleKills': 0,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstInhibitorAssist': False,
#                              'firstInhibitorKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': True,
#                              'goldEarned': 17742,
#                              'goldSpent': 16950,
#                              'inhibitorKills': 0,
#                              'item0': 1038,
#                              'item1': 6676,
#                              'item2': 6673,
#                              'item3': 3031,
#                              'item4': 3036,
#                              'item5': 3006,
#                              'item6': 3363,
#                              'killingSprees': 2,
#                              'kills': 6,
#                              'largestCriticalStrike': 942,
#                              'largestKillingSpree': 2,
#                              'largestMultiKill': 1,
#                              'longestTimeSpentLiving': 1016,
#                              'magicDamageDealt': 2668,
#                              'magicDamageDealtToChampions': 287,
#                              'magicalDamageTaken': 8526,
#                              'neutralMinionsKilled': 22,
#                              'neutralMinionsKilledEnemyJungle': 0,
#                              'neutralMinionsKilledTeamJungle': 14,
#                              'objectivePlayerScore': 0,
#                              'participantId': 1,
#                              'pentaKills': 0,
#                              'perk0': 8008,
#                              'perk0Var1': 2,
#                              'perk0Var2': 0,
#                              'perk0Var3': 0,
#                              'perk1': 8009,
#                              'perk1Var1': 1400,
#                              'perk1Var2': 0,
#                              'perk1Var3': 0,
#                              'perk2': 9103,
#                              'perk2Var1': 25,
#                              'perk2Var2': 10,
#                              'perk2Var3': 0,
#                              'perk3': 8017,
#                              'perk3Var1': 1491,
#                              'perk3Var2': 0,
#                              'perk3Var3': 0,
#                              'perk4': 8139,
#                              'perk4Var1': 1105,
#                              'perk4Var2': 0,
#                              'perk4Var3': 0,
#                              'perk5': 8135,
#                              'perk5Var1': 1431,
#                              'perk5Var2': 5,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8000,
#                              'perkSubStyle': 8100,
#                              'physicalDamageDealt': 191946,
#                              'physicalDamageDealtToChampions': 22228,
#                              'physicalDamageTaken': 10100,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 0,
#                              'playerScore5': 1,
#                              'playerScore6': 0,
#                              'playerScore7': 0,
#                              'playerScore8': 0,
#                              'playerScore9': 1,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'statPerk0': 5005,
#                              'statPerk1': 5008,
#                              'statPerk2': 5002,
#                              'timeCCingOthers': 8,
#                              'totalDamageDealt': 196285,
#                              'totalDamageDealtToChampions': 22747,
#                              'totalDamageTaken': 19626,
#                              'totalHeal': 4535,
#                              'totalMinionsKilled': 235,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 180,
#                              'totalUnitsHealed': 3,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 1671,
#                              'trueDamageDealtToChampions': 231,
#                              'trueDamageTaken': 1000,
#                              'turretKills': 4,
#                              'unrealKills': 0,
#                              'visionScore': 22,
#                              'visionWardsBoughtInGame': 3,
#                              'wardsKilled': 9,
#                              'wardsPlaced': 8,
#                              'win': False},
#                    'teamId': 100,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 8.3,
#                                                        '10-20': 8.3,
#                                                        '20-30': 5.6},
#                                 'damageTakenPerMinDeltas': {'0-10': 191.7,
#                                                             '10-20': 504.1,
#                                                             '20-30': 975.2},
#                                 'goldPerMinDeltas': {'0-10': 385.8,
#                                                      '10-20': 566.6,
#                                                      '20-30': 581.1},
#                                 'lane': 'JUNGLE',
#                                 'participantId': 1,
#                                 'role': 'NONE',
#                                 'xpPerMinDeltas': {'0-10': 390.6,
#                                                    '10-20': 454.09999999999997,
#                                                    '20-30': 434.7}}},
#                   {'championId': 48,
#                    'participantId': 2,
#                    'spell1Id': 14,
#                    'spell2Id': 4,
#                    'stats': {'assists': 8,
#                              'champLevel': 13,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 2797,
#                              'damageDealtToTurrets': 1630,
#                              'damageSelfMitigated': 28087,
#                              'deaths': 12,
#                              'doubleKills': 0,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstInhibitorAssist': False,
#                              'firstInhibitorKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 8382,
#                              'goldSpent': 6750,
#                              'inhibitorKills': 0,
#                              'item0': 3190,
#                              'item1': 3857,
#                              'item2': 0,
#                              'item3': 1011,
#                              'item4': 3076,
#                              'item5': 3158,
#                              'item6': 3364,
#                              'killingSprees': 0,
#                              'kills': 1,
#                              'largestCriticalStrike': 1,
#                              'largestKillingSpree': 0,
#                              'largestMultiKill': 1,
#                              'longestTimeSpentLiving': 231,
#                              'magicDamageDealt': 1902,
#                              'magicDamageDealtToChampions': 1569,
#                              'magicalDamageTaken': 13703,
#                              'neutralMinionsKilled': 0,
#                              'neutralMinionsKilledEnemyJungle': 0,
#                              'neutralMinionsKilledTeamJungle': 0,
#                              'objectivePlayerScore': 0,
#                              'participantId': 2,
#                              'pentaKills': 0,
#                              'perk0': 9923,
#                              'perk0Var1': 30,
#                              'perk0Var2': 71,
#                              'perk0Var3': 0,
#                              'perk1': 8126,
#                              'perk1Var1': 372,
#                              'perk1Var2': 0,
#                              'perk1Var3': 0,
#                              'perk2': 8136,
#                              'perk2Var1': 19,
#                              'perk2Var2': 30,
#                              'perk2Var3': 0,
#                              'perk3': 8105,
#                              'perk3Var1': 12,
#                              'perk3Var2': 5,
#                              'perk3Var3': 0,
#                              'perk4': 8345,
#                              'perk4Var1': 3,
#                              'perk4Var2': 0,
#                              'perk4Var3': 0,
#                              'perk5': 8352,
#                              'perk5Var1': 198,
#                              'perk5Var2': 1332,
#                              'perk5Var3': 43,
#                              'perkPrimaryStyle': 8100,
#                              'perkSubStyle': 8300,
#                              'physicalDamageDealt': 24474,
#                              'physicalDamageDealtToChampions': 2677,
#                              'physicalDamageTaken': 17216,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 0,
#                              'playerScore5': 0,
#                              'playerScore6': 0,
#                              'playerScore7': 0,
#                              'playerScore8': 0,
#                              'playerScore9': 1,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'statPerk0': 5005,
#                              'statPerk1': 5008,
#                              'statPerk2': 5002,
#                              'timeCCingOthers': 37,
#                              'totalDamageDealt': 37480,
#                              'totalDamageDealtToChampions': 5106,
#                              'totalDamageTaken': 33964,
#                              'totalHeal': 7977,
#                              'totalMinionsKilled': 52,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 384,
#                              'totalUnitsHealed': 1,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 11103,
#                              'trueDamageDealtToChampions': 859,
#                              'trueDamageTaken': 3044,
#                              'turretKills': 0,
#                              'unrealKills': 0,
#                              'visionScore': 108,
#                              'visionWardsBoughtInGame': 12,
#                              'wardsKilled': 12,
#                              'wardsPlaced': 73,
#                              'win': False},
#                    'teamId': 100,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 1.7999999999999998,
#                                                        '10-20': 2.2,
#                                                        '20-30': 1.1},
#                                 'damageTakenPerMinDeltas': {'0-10': 671.4000000000001,
#                                                             '10-20': 1006.6,
#                                                             '20-30': 1152.3},
#                                 'goldPerMinDeltas': {'0-10': 215,
#                                                      '10-20': 274.7,
#                                                      '20-30': 195.2},
#                                 'lane': 'BOTTOM',
#                                 'participantId': 2,
#                                 'role': 'SOLO',
#                                 'xpPerMinDeltas': {'0-10': 263.2,
#                                                    '10-20': 274,
#                                                    '20-30': 421.1}}},
#                   {'championId': 56,
#                    'participantId': 3,
#                    'spell1Id': 11,
#                    'spell2Id': 4,
#                    'stats': {'assists': 8,
#                              'champLevel': 15,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 28652,
#                              'damageDealtToTurrets': 450,
#                              'damageSelfMitigated': 28972,
#                              'deaths': 5,
#                              'doubleKills': 0,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstInhibitorAssist': False,
#                              'firstInhibitorKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 12920,
#                              'goldSpent': 12725,
#                              'inhibitorKills': 0,
#                              'item0': 6631,
#                              'item1': 3143,
#                              'item2': 3105,
#                              'item3': 3053,
#                              'item4': 1029,
#                              'item5': 3158,
#                              'item6': 3364,
#                              'killingSprees': 1,
#                              'kills': 8,
#                              'largestCriticalStrike': 0,
#                              'largestKillingSpree': 6,
#                              'largestMultiKill': 1,
#                              'longestTimeSpentLiving': 1183,
#                              'magicDamageDealt': 8666,
#                              'magicDamageDealtToChampions': 1328,
#                              'magicalDamageTaken': 12512,
#                              'neutralMinionsKilled': 149,
#                              'neutralMinionsKilledEnemyJungle': 5,
#                              'neutralMinionsKilledTeamJungle': 105,
#                              'objectivePlayerScore': 0,
#                              'participantId': 3,
#                              'pentaKills': 0,
#                              'perk0': 8008,
#                              'perk0Var1': 1,
#                              'perk0Var2': 40,
#                              'perk0Var3': 0,
#                              'perk1': 9111,
#                              'perk1Var1': 1098,
#                              'perk1Var2': 320,
#                              'perk1Var3': 0,
#                              'perk2': 9104,
#                              'perk2Var1': 13,
#                              'perk2Var2': 30,
#                              'perk2Var3': 0,
#                              'perk3': 8299,
#                              'perk3Var1': 447,
#                              'perk3Var2': 0,
#                              'perk3Var3': 0,
#                              'perk4': 8136,
#                              'perk4Var1': 18,
#                              'perk4Var2': 30,
#                              'perk4Var3': 0,
#                              'perk5': 8106,
#                              'perk5Var1': 5,
#                              'perk5Var2': 0,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8000,
#                              'perkSubStyle': 8100,
#                              'physicalDamageDealt': 158624,
#                              'physicalDamageDealtToChampions': 14884,
#                              'physicalDamageTaken': 16881,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 1,
#                              'playerScore4': 0,
#                              'playerScore5': 0,
#                              'playerScore6': 0,
#                              'playerScore7': 2,
#                              'playerScore8': 0,
#                              'playerScore9': 1,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'statPerk0': 5005,
#                              'statPerk1': 5008,
#                              'statPerk2': 5002,
#                              'timeCCingOthers': 198,
#                              'totalDamageDealt': 182778,
#                              'totalDamageDealtToChampions': 16767,
#                              'totalDamageTaken': 32140,
#                              'totalHeal': 13689,
#                              'totalMinionsKilled': 27,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 771,
#                              'totalUnitsHealed': 1,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 15486,
#                              'trueDamageDealtToChampions': 555,
#                              'trueDamageTaken': 2746,
#                              'turretKills': 1,
#                              'unrealKills': 0,
#                              'visionScore': 54,
#                              'visionWardsBoughtInGame': 5,
#                              'wardsKilled': 11,
#                              'wardsPlaced': 21,
#                              'win': False},
#                    'teamId': 100,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 1.1,
#                                                        '10-20': 1.4,
#                                                        '20-30': 0.2},
#                                 'damageTakenPerMinDeltas': {'0-10': 614.2,
#                                                             '10-20': 839.6999999999999,
#                                                             '20-30': 1360.7},
#                                 'goldPerMinDeltas': {'0-10': 335.3,
#                                                      '10-20': 478.7,
#                                                      '20-30': 392.3},
#                                 'lane': 'JUNGLE',
#                                 'participantId': 3,
#                                 'role': 'NONE',
#                                 'xpPerMinDeltas': {'0-10': 431.8,
#                                                    '10-20': 476,
#                                                    '20-30': 451.6}}},
#                   {'championId': 30,
#                    'participantId': 4,
#                    'spell1Id': 4,
#                    'spell2Id': 12,
#                    'stats': {'assists': 11,
#                              'champLevel': 16,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 6238,
#                              'damageDealtToTurrets': 0,
#                              'damageSelfMitigated': 10441,
#                              'deaths': 7,
#                              'doubleKills': 0,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstInhibitorAssist': False,
#                              'firstInhibitorKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 10749,
#                              'goldSpent': 10475,
#                              'inhibitorKills': 0,
#                              'item0': 6653,
#                              'item1': 3135,
#                              'item2': 3157,
#                              'item3': 0,
#                              'item4': 3020,
#                              'item5': 0,
#                              'item6': 3363,
#                              'killingSprees': 0,
#                              'kills': 2,
#                              'largestCriticalStrike': 0,
#                              'largestKillingSpree': 0,
#                              'largestMultiKill': 1,
#                              'longestTimeSpentLiving': 457,
#                              'magicDamageDealt': 148946,
#                              'magicDamageDealtToChampions': 23546,
#                              'magicalDamageTaken': 8946,
#                              'neutralMinionsKilled': 21,
#                              'neutralMinionsKilledEnemyJungle': 11,
#                              'neutralMinionsKilledTeamJungle': 9,
#                              'objectivePlayerScore': 0,
#                              'participantId': 4,
#                              'pentaKills': 0,
#                              'perk0': 8128,
#                              'perk0Var1': 762,
#                              'perk0Var2': 12,
#                              'perk0Var3': 0,
#                              'perk1': 8126,
#                              'perk1Var1': 758,
#                              'perk1Var2': 0,
#                              'perk1Var3': 0,
#                              'perk2': 8138,
#                              'perk2Var1': 30,
#                              'perk2Var2': 0,
#                              'perk2Var3': 0,
#                              'perk3': 8135,
#                              'perk3Var1': 2754,
#                              'perk3Var2': 5,
#                              'perk3Var3': 0,
#                              'perk4': 8009,
#                              'perk4Var1': 2991,
#                              'perk4Var2': 0,
#                              'perk4Var3': 0,
#                              'perk5': 8014,
#                              'perk5Var1': 425,
#                              'perk5Var2': 0,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8100,
#                              'perkSubStyle': 8000,
#                              'physicalDamageDealt': 3367,
#                              'physicalDamageDealtToChampions': 294,
#                              'physicalDamageTaken': 9889,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 1,
#                              'playerScore5': 0,
#                              'playerScore6': 0,
#                              'playerScore7': 1,
#                              'playerScore8': 0,
#                              'playerScore9': 1,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'statPerk0': 5008,
#                              'statPerk1': 5008,
#                              'statPerk2': 5002,
#                              'timeCCingOthers': 22,
#                              'totalDamageDealt': 152932,
#                              'totalDamageDealtToChampions': 24459,
#                              'totalDamageTaken': 19512,
#                              'totalHeal': 2594,
#                              'totalMinionsKilled': 193,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 280,
#                              'totalUnitsHealed': 1,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 617,
#                              'trueDamageDealtToChampions': 617,
#                              'trueDamageTaken': 676,
#                              'turretKills': 0,
#                              'unrealKills': 0,
#                              'visionScore': 21,
#                              'visionWardsBoughtInGame': 3,
#                              'wardsKilled': 3,
#                              'wardsPlaced': 12,
#                              'win': False},
#                    'teamId': 100,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 7.3,
#                                                        '10-20': 5.9,
#                                                        '20-30': 4.9},
#                                 'csDiffPerMinDeltas': {'0-10': -1.1000000000000005,
#                                                        '10-20': -1.6,
#                                                        '20-30': -2.3},
#                                 'damageTakenDiffPerMinDeltas': {'0-10': -199.59999999999997,
#                                                                 '10-20': -526.0999999999999,
#                                                                 '20-30': -37.99999999999994},
#                                 'damageTakenPerMinDeltas': {'0-10': 213.3,
#                                                             '10-20': 263,
#                                                             '20-30': 1141.2},
#                                 'goldPerMinDeltas': {'0-10': 248.10000000000002,
#                                                      '10-20': 324.20000000000005,
#                                                      '20-30': 359.9},
#                                 'lane': 'TOP',
#                                 'participantId': 4,
#                                 'role': 'SOLO',
#                                 'xpDiffPerMinDeltas': {'0-10': -38.20000000000002,
#                                                        '10-20': -51.20000000000002,
#                                                        '20-30': -178},
#                                 'xpPerMinDeltas': {'0-10': 420.6,
#                                                    '10-20': 436.1,
#                                                    '20-30': 479.8}}},
#                   {'championId': 13,
#                    'participantId': 5,
#                    'spell1Id': 12,
#                    'spell2Id': 4,
#                    'stats': {'assists': 4,
#                              'champLevel': 16,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 4282,
#                              'damageDealtToTurrets': 124,
#                              'damageSelfMitigated': 12165,
#                              'deaths': 6,
#                              'doubleKills': 0,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstInhibitorAssist': False,
#                              'firstInhibitorKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 11699,
#                              'goldSpent': 10910,
#                              'inhibitorKills': 0,
#                              'item0': 6656,
#                              'item1': 1052,
#                              'item2': 3157,
#                              'item3': 3158,
#                              'item4': 0,
#                              'item5': 3040,
#                              'item6': 3340,
#                              'killingSprees': 1,
#                              'kills': 3,
#                              'largestCriticalStrike': 0,
#                              'largestKillingSpree': 2,
#                              'largestMultiKill': 1,
#                              'longestTimeSpentLiving': 1386,
#                              'magicDamageDealt': 166816,
#                              'magicDamageDealtToChampions': 10388,
#                              'magicalDamageTaken': 10577,
#                              'neutralMinionsKilled': 22,
#                              'neutralMinionsKilledEnemyJungle': 7,
#                              'neutralMinionsKilledTeamJungle': 8,
#                              'objectivePlayerScore': 0,
#                              'participantId': 5,
#                              'pentaKills': 0,
#                              'perk0': 8230,
#                              'perk0Var1': 8,
#                              'perk0Var2': 0,
#                              'perk0Var3': 0,
#                              'perk1': 8226,
#                              'perk1Var1': 250,
#                              'perk1Var2': 1054,
#                              'perk1Var3': 0,
#                              'perk2': 8210,
#                              'perk2Var1': 6,
#                              'perk2Var2': 0,
#                              'perk2Var3': 0,
#                              'perk3': 8232,
#                              'perk3Var1': 3,
#                              'perk3Var2': 20,
#                              'perk3Var3': 0,
#                              'perk4': 8345,
#                              'perk4Var1': 3,
#                              'perk4Var2': 0,
#                              'perk4Var3': 0,
#                              'perk5': 8352,
#                              'perk5Var1': 220,
#                              'perk5Var2': 1423,
#                              'perk5Var3': 910,
#                              'perkPrimaryStyle': 8200,
#                              'perkSubStyle': 8300,
#                              'physicalDamageDealt': 6387,
#                              'physicalDamageDealtToChampions': 421,
#                              'physicalDamageTaken': 11384,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 0,
#                              'playerScore5': 0,
#                              'playerScore6': 1,
#                              'playerScore7': 0,
#                              'playerScore8': 0,
#                              'playerScore9': 1,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'statPerk0': 5005,
#                              'statPerk1': 5008,
#                              'statPerk2': 5003,
#                              'timeCCingOthers': 14,
#                              'totalDamageDealt': 173204,
#                              'totalDamageDealtToChampions': 10810,
#                              'totalDamageTaken': 24038,
#                              'totalHeal': 1673,
#                              'totalMinionsKilled': 237,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 86,
#                              'totalUnitsHealed': 1,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 0,
#                              'trueDamageDealtToChampions': 0,
#                              'trueDamageTaken': 2076,
#                              'turretKills': 0,
#                              'unrealKills': 0,
#                              'visionScore': 24,
#                              'visionWardsBoughtInGame': 3,
#                              'wardsKilled': 5,
#                              'wardsPlaced': 12,
#                              'win': False},
#                    'teamId': 100,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 7.699999999999999,
#                                                        '10-20': 9.7,
#                                                        '20-30': 5.7},
#                                 'csDiffPerMinDeltas': {'0-10': -1.1000000000000005,
#                                                        '10-20': -2.5,
#                                                        '20-30': -2.2999999999999994},
#                                 'damageTakenDiffPerMinDeltas': {'0-10': 83.39999999999999,
#                                                                 '10-20': -41.900000000000006,
#                                                                 '20-30': 410.1000000000001},
#                                 'damageTakenPerMinDeltas': {'0-10': 319.2,
#                                                             '10-20': 162.1,
#                                                             '20-30': 1200.8000000000002},
#                                 'goldPerMinDeltas': {'0-10': 292.1,
#                                                      '10-20': 382.7,
#                                                      '20-30': 403.9},
#                                 'lane': 'MIDDLE',
#                                 'participantId': 5,
#                                 'role': 'SOLO',
#                                 'xpDiffPerMinDeltas': {'0-10': -6.199999999999989,
#                                                        '10-20': -46.799999999999955,
#                                                        '20-30': -274.90000000000003},
#                                 'xpPerMinDeltas': {'0-10': 441.8,
#                                                    '10-20': 582.4000000000001,
#                                                    '20-30': 501.2}}},
#                   {'championId': 164,
#                    'participantId': 6,
#                    'spell1Id': 4,
#                    'spell2Id': 12,
#                    'stats': {'assists': 5,
#                              'champLevel': 17,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 11083,
#                              'damageDealtToTurrets': 5128,
#                              'damageSelfMitigated': 24070,
#                              'deaths': 9,
#                              'doubleKills': 0,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstInhibitorAssist': False,
#                              'firstInhibitorKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 13387,
#                              'goldSpent': 12733,
#                              'inhibitorKills': 0,
#                              'item0': 3078,
#                              'item1': 3074,
#                              'item2': 3181,
#                              'item3': 3044,
#                              'item4': 1028,
#                              'item5': 3111,
#                              'item6': 3364,
#                              'killingSprees': 1,
#                              'kills': 6,
#                              'largestCriticalStrike': 0,
#                              'largestKillingSpree': 3,
#                              'largestMultiKill': 1,
#                              'longestTimeSpentLiving': 343,
#                              'magicDamageDealt': 1881,
#                              'magicDamageDealtToChampions': 1819,
#                              'magicalDamageTaken': 7297,
#                              'neutralMinionsKilled': 8,
#                              'neutralMinionsKilledEnemyJungle': 4,
#                              'neutralMinionsKilledTeamJungle': 4,
#                              'objectivePlayerScore': 0,
#                              'participantId': 6,
#                              'pentaKills': 0,
#                              'perk0': 8437,
#                              'perk0Var1': 738,
#                              'perk0Var2': 530,
#                              'perk0Var3': 0,
#                              'perk1': 8401,
#                              'perk1Var1': 593,
#                              'perk1Var2': 0,
#                              'perk1Var3': 0,
#                              'perk2': 8473,
#                              'perk2Var1': 715,
#                              'perk2Var2': 0,
#                              'perk2Var3': 0,
#                              'perk3': 8453,
#                              'perk3Var1': 555,
#                              'perk3Var2': 458,
#                              'perk3Var3': 0,
#                              'perk4': 8304,
#                              'perk4Var1': 10,
#                              'perk4Var2': 3,
#                              'perk4Var3': 0,
#                              'perk5': 8345,
#                              'perk5Var1': 3,
#                              'perk5Var2': 0,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8400,
#                              'perkSubStyle': 8300,
#                              'physicalDamageDealt': 132767,
#                              'physicalDamageDealtToChampions': 9997,
#                              'physicalDamageTaken': 20060,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 0,
#                              'playerScore5': 0,
#                              'playerScore6': 0,
#                              'playerScore7': 1,
#                              'playerScore8': 0,
#                              'playerScore9': 1,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'statPerk0': 5005,
#                              'statPerk1': 5008,
#                              'statPerk2': 5003,
#                              'timeCCingOthers': 16,
#                              'totalDamageDealt': 174881,
#                              'totalDamageDealtToChampions': 18855,
#                              'totalDamageTaken': 30203,
#                              'totalHeal': 4815,
#                              'totalMinionsKilled': 233,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 255,
#                              'totalUnitsHealed': 1,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 40233,
#                              'trueDamageDealtToChampions': 7039,
#                              'trueDamageTaken': 2845,
#                              'turretKills': 2,
#                              'unrealKills': 0,
#                              'visionScore': 27,
#                              'visionWardsBoughtInGame': 4,
#                              'wardsKilled': 6,
#                              'wardsPlaced': 8,
#                              'win': True},
#                    'teamId': 200,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 8.4,
#                                                        '10-20': 7.5,
#                                                        '20-30': 7.2},
#                                 'csDiffPerMinDeltas': {'0-10': 1.1000000000000005,
#                                                        '10-20': 1.6,
#                                                        '20-30': 2.3},
#                                 'damageTakenDiffPerMinDeltas': {'0-10': 199.59999999999997,
#                                                                 '10-20': 526.0999999999999,
#                                                                 '20-30': 37.99999999999994},
#                                 'damageTakenPerMinDeltas': {'0-10': 412.9,
#                                                             '10-20': 789.0999999999999,
#                                                             '20-30': 1179.1999999999998},
#                                 'goldPerMinDeltas': {'0-10': 293.3,
#                                                      '10-20': 328.20000000000005,
# ...
#                                                        '10-20': 2.5,
#                                                        '20-30': 2.2999999999999994},
#                                 'damageTakenDiffPerMinDeltas': {'0-10': -83.39999999999999,
#                                                                 '10-20': 41.900000000000006,
#                                                                 '20-30': -410.1000000000001},
#                                 'damageTakenPerMinDeltas': {'0-10': 235.8,
#                                                             '10-20': 204,
#                                                             '20-30': 790.7},
#                                 'goldPerMinDeltas': {'0-10': 279.3,
#                                                      '10-20': 461.7,
#                                                      '20-30': 763.2},
#                                 'lane': 'MIDDLE',
#                                 'participantId': 8,
#                                 'role': 'SOLO',
#                                 'xpDiffPerMinDeltas': {'0-10': 6.199999999999989,
#                                                        '10-20': 46.799999999999955,
#                                                        '20-30': 274.90000000000003},
#                                 'xpPerMinDeltas': {'0-10': 448,
#                                                    '10-20': 629.2,
#                                                    '20-30': 776.1}}},
#                   {'championId': 201,
#                    'participantId': 9,
#                    'spell1Id': 14,
#                    'spell2Id': 4,
#                    'stats': {'assists': 27,
#                              'champLevel': 15,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 2142,
#                              'damageDealtToTurrets': 938,
#                              'damageSelfMitigated': 18708,
#                              'deaths': 2,
#                              'doubleKills': 0,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': False,
#                              'firstInhibitorAssist': True,
#                              'firstInhibitorKill': False,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 9498,
#                              'goldSpent': 8125,
#                              'inhibitorKills': 0,
#                              'item0': 0,
#                              'item1': 3860,
#                              'item2': 3190,
#                              'item3': 3050,
#                              'item4': 3801,
#                              'item5': 3111,
#                              'item6': 3364,
#                              'killingSprees': 0,
#                              'kills': 2,
#                              'largestCriticalStrike': 0,
#                              'largestKillingSpree': 0,
#                              'largestMultiKill': 1,
#                              'longestTimeSpentLiving': 739,
#                              'magicDamageDealt': 12071,
#                              'magicDamageDealtToChampions': 5939,
#                              'magicalDamageTaken': 6679,
#                              'neutralMinionsKilled': 0,
#                              'neutralMinionsKilledEnemyJungle': 0,
#                              'neutralMinionsKilledTeamJungle': 0,
#                              'objectivePlayerScore': 0,
#                              'participantId': 9,
#                              'pentaKills': 0,
#                              'perk0': 8465,
#                              'perk0Var1': 3249,
#                              'perk0Var2': 0,
#                              'perk0Var3': 0,
#                              'perk1': 8463,
#                              'perk1Var1': 1473,
#                              'perk1Var2': 0,
#                              'perk1Var3': 0,
#                              'perk2': 8473,
#                              'perk2Var1': 417,
#                              'perk2Var2': 0,
#                              'perk2Var3': 0,
#                              'perk3': 8242,
#                              'perk3Var1': 80,
#                              'perk3Var2': 0,
#                              'perk3Var3': 0,
#                              'perk4': 8352,
#                              'perk4Var1': 79,
#                              'perk4Var2': 462,
#                              'perk4Var3': 0,
#                              'perk5': 8316,
#                              'perk5Var1': 905,
#                              'perk5Var2': 0,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8400,
#                              'perkSubStyle': 8300,
#                              'physicalDamageDealt': 6476,
#                              'physicalDamageDealtToChampions': 846,
#                              'physicalDamageTaken': 10074,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 0,
#                              'playerScore4': 1,
#                              'playerScore5': 0,
#                              'playerScore6': 0,
#                              'playerScore7': 0,
#                              'playerScore8': 0,
#                              'playerScore9': 1,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'statPerk0': 5008,
#                              'statPerk1': 5002,
#                              'statPerk2': 5002,
#                              'timeCCingOthers': 34,
#                              'totalDamageDealt': 27584,
#                              'totalDamageDealtToChampions': 7511,
#                              'totalDamageTaken': 17014,
#                              'totalHeal': 4519,
#                              'totalMinionsKilled': 38,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 175,
#                              'totalUnitsHealed': 5,
#                              'tripleKills': 0,
#                              'trueDamageDealt': 9036,
#                              'trueDamageDealtToChampions': 726,
#                              'trueDamageTaken': 260,
#                              'turretKills': 0,
#                              'unrealKills': 0,
#                              'visionScore': 84,
#                              'visionWardsBoughtInGame': 11,
#                              'wardsKilled': 16,
#                              'wardsPlaced': 48,
#                              'win': True},
#                    'teamId': 200,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 1.8,
#                                                        '10-20': 1.5,
#                                                        '20-30': 0.5},
#                                 'damageTakenPerMinDeltas': {'0-10': 258.5,
#                                                             '10-20': 294.5,
#                                                             '20-30': 858.8},
#                                 'goldPerMinDeltas': {'0-10': 175.4,
#                                                      '10-20': 247.7,
#                                                      '20-30': 357.5},
#                                 'lane': 'BOTTOM',
#                                 'participantId': 9,
#                                 'role': 'DUO_SUPPORT',
#                                 'xpPerMinDeltas': {'0-10': 227.1,
#                                                    '10-20': 332.6,
#                                                    '20-30': 600.8}}},
#                   {'championId': 145,
#                    'participantId': 10,
#                    'spell1Id': 7,
#                    'spell2Id': 4,
#                    'stats': {'assists': 10,
#                              'champLevel': 17,
#                              'combatPlayerScore': 0,
#                              'damageDealtToObjectives': 28103,
#                              'damageDealtToTurrets': 5319,
#                              'damageSelfMitigated': 13731,
#                              'deaths': 3,
#                              'doubleKills': 3,
#                              'firstBloodAssist': False,
#                              'firstBloodKill': True,
#                              'firstInhibitorAssist': False,
#                              'firstInhibitorKill': True,
#                              'firstTowerAssist': False,
#                              'firstTowerKill': False,
#                              'goldEarned': 17245,
#                              'goldSpent': 16850,
#                              'inhibitorKills': 1,
#                              'item0': 8001,
#                              'item1': 0,
#                              'item2': 0,
#                              'item3': 0,
#                              'item4': 0,
#                              'item5': 0,
#                              'item6': 3363,
#                              'killingSprees': 3,
#                              'kills': 12,
#                              'largestCriticalStrike': 610,
#                              'largestKillingSpree': 7,
#                              'largestMultiKill': 3,
#                              'longestTimeSpentLiving': 1510,
#                              'magicDamageDealt': 30456,
#                              'magicDamageDealtToChampions': 9355,
#                              'magicalDamageTaken': 6986,
#                              'neutralMinionsKilled': 52,
#                              'neutralMinionsKilledEnemyJungle': 0,
#                              'neutralMinionsKilledTeamJungle': 39,
#                              'objectivePlayerScore': 0,
#                              'participantId': 10,
#                              'pentaKills': 0,
#                              'perk0': 9923,
#                              'perk0Var1': 61,
#                              'perk0Var2': 88,
#                              'perk0Var3': 0,
#                              'perk1': 8139,
#                              'perk1Var1': 928,
#                              'perk1Var2': 0,
#                              'perk1Var3': 0,
#                              'perk2': 8138,
#                              'perk2Var1': 18,
#                              'perk2Var2': 0,
#                              'perk2Var3': 0,
#                              'perk3': 8135,
#                              'perk3Var1': 3677,
#                              'perk3Var2': 5,
#                              'perk3Var3': 0,
#                              'perk4': 8345,
#                              'perk4Var1': 3,
#                              'perk4Var2': 0,
#                              'perk4Var3': 0,
#                              'perk5': 8347,
#                              'perk5Var1': 0,
#                              'perk5Var2': 0,
#                              'perk5Var3': 0,
#                              'perkPrimaryStyle': 8100,
#                              'perkSubStyle': 8300,
#                              'physicalDamageDealt': 190537,
#                              'physicalDamageDealtToChampions': 18161,
#                              'physicalDamageTaken': 11031,
#                              'playerScore0': 0,
#                              'playerScore1': 0,
#                              'playerScore2': 0,
#                              'playerScore3': 1,
#                              'playerScore4': 0,
#                              'playerScore5': 1,
#                              'playerScore6': 0,
#                              'playerScore7': 1,
#                              'playerScore8': 0,
#                              'playerScore9': 1,
#                              'quadraKills': 0,
#                              'sightWardsBoughtInGame': 0,
#                              'statPerk0': 5005,
#                              'statPerk1': 5008,
#                              'statPerk2': 5002,
#                              'timeCCingOthers': 6,
#                              'totalDamageDealt': 227720,
#                              'totalDamageDealtToChampions': 28830,
#                              'totalDamageTaken': 19612,
#                              'totalHeal': 8931,
#                              'totalMinionsKilled': 240,
#                              'totalPlayerScore': 0,
#                              'totalScoreRank': 0,
#                              'totalTimeCrowdControlDealt': 88,
#                              'totalUnitsHealed': 4,
#                              'tripleKills': 1,
#                              'trueDamageDealt': 6726,
#                              'trueDamageDealtToChampions': 1312,
#                              'trueDamageTaken': 1594,
#                              'turretKills': 2,
#                              'unrealKills': 0,
#                              'visionScore': 43,
#                              'visionWardsBoughtInGame': 4,
#                              'wardsKilled': 15,
#                              'wardsPlaced': 11,
#                              'win': True},
#                    'teamId': 200,
#                    'timeline': {'creepsPerMinDeltas': {'0-10': 7,
#                                                        '10-20': 10.2,
#                                                        '20-30': 5.1000000000000005},
#                                 'damageTakenPerMinDeltas': {'0-10': 282.20000000000005,
#                                                             '10-20': 305.1,
#                                                             '20-30': 915.5},
#                                 'goldPerMinDeltas': {'0-10': 329,
#                                                      '10-20': 489.8,
#                                                      '20-30': 611.2},
#                                 'lane': 'BOTTOM',
#                                 'participantId': 10,
#                                 'role': 'DUO_CARRY',
#                                 'xpPerMinDeltas': {'0-10': 320.20000000000005,
#                                                    '10-20': 515.6,
#                                                    '20-30': 656.3}}}],
#  'platformId': 'KR',
#  'queueId': 420,
#  'seasonId': 13,
#  'teams': [{'bans': [{'championId': 126, 'pickTurn': 1},
#                      {'championId': 246, 'pickTurn': 2},
#                      {'championId': 89, 'pickTurn': 3},
#                      {'championId': 412, 'pickTurn': 4},
#                      {'championId': -1, 'pickTurn': 5}],
#             'baronKills': 0,
#             'dominionVictoryScore': 0,
#             'dragonKills': 1,
#             'firstBaron': False,
#             'firstBlood': False,
#             'firstDragon': False,
#             'firstInhibitor': False,
#             'firstRiftHerald': True,
#             'firstTower': True,
#             'inhibitorKills': 0,
#             'riftHeraldKills': 2,
#             'teamId': 100,
#             'towerKills': 5,
#             'vilemawKills': 0,
#             'win': 'Fail'},
#            {'bans': [{'championId': 134, 'pickTurn': 6},
#                      {'championId': -1, 'pickTurn': 7},
#                      {'championId': -1, 'pickTurn': 8},
#                      {'championId': 412, 'pickTurn': 9},
#                      {'championId': 7, 'pickTurn': 10}],
#             'baronKills': 2,
#             'dominionVictoryScore': 0,
#             'dragonKills': 3,
#             'firstBaron': True,
#             'firstBlood': True,
#             'firstDragon': True,
#             'firstInhibitor': True,
#             'firstRiftHerald': False,
#             'firstTower': False,
#             'inhibitorKills': 3,
#             'riftHeraldKills': 0,
#             'teamId': 200,
#             'towerKills': 11,
#             'vilemawKills': 0,
#             'win': 'Win'}]}
